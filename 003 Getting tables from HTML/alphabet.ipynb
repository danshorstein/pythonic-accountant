# %%
#  238
import pandas as pd

# %%
url = 'https://www.sec.gov/Archives/edgar/data/1652044/000165204419000004/goog10-kq42018.htm#s60D13494C77354D8AED0E72D61E53B98'

# %%
df = pd.read_html(url)

# %%
len(df)
# Out:
# 382

# %%
df[238].head(10)
# Out:
#                                                    0                        1  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN  As of December 31, 2017
# 3                                             Assets                      NaN
# 4                                    Current assets:                      NaN
# 5                          Cash and cash equivalents                        $
# 6                              Marketable securities                    91156
# 7  Total cash, cash equivalents, and marketable s...                   101871
# 8  Accounts receivable, net of allowance of $674 ...                    18336
# 9                       Income taxes receivable, net                      369
#
#                          2                        3   4  \
# ...

# %%
balsht = df[238][[0, 2, 6]]

# %%
balsht.head(10)
# Out:
#                                                    0                        2  \
# 0                                                NaN                      NaN
# 1                                                NaN                      NaN
# 2                                                NaN  As of December 31, 2017
# 3                                             Assets                      NaN
# 4                                    Current assets:                      NaN
# 5                          Cash and cash equivalents                    10715
# 6                              Marketable securities                    91156
# 7  Total cash, cash equivalents, and marketable s...                   101871
# 8  Accounts receivable, net of allowance of $674 ...                    18336
# 9                       Income taxes receivable, net                      369
#
#                         6
# 0                     NaN
# 1                     NaN
# 2  As ofDecember 31, 2018
# ...

# %%
balsht.columns = ['Account', '12/31/17', '12/31/18']

# %%
balsht.head()
# Out:
#            Account                 12/31/17                12/31/18
# 0              NaN                      NaN                     NaN
# 1              NaN                      NaN                     NaN
# 2              NaN  As of December 31, 2017  As ofDecember 31, 2018
# 3           Assets                      NaN                     NaN
# 4  Current assets:                      NaN                     NaN

# %%
balsht = balsht.dropna()
balsht.head(10)
# Out:
#                                               Account 12/31/17 12/31/18
# 5                           Cash and cash equivalents    10715    16701
# 6                               Marketable securities    91156    92439
# 7   Total cash, cash equivalents, and marketable s...   101871   109140
# 8   Accounts receivable, net of allowance of $674 ...    18336    20838
# 9                        Income taxes receivable, net      369      355
# 10                                          Inventory      749     1107
# 11                               Other current assets     2983     4236
# 12                               Total current assets   124308   135676
# 13                         Non-marketable investments     7813    13859
# 14                              Deferred income taxes      680      737

# %%
balsht = balsht.reset_index(drop=True)

# %%
balsht.head()
# Out:
#                                              Account 12/31/17 12/31/18
# 0                          Cash and cash equivalents    10715    16701
# 1                              Marketable securities    91156    92439
# 2  Total cash, cash equivalents, and marketable s...   101871   109140
# 3  Accounts receivable, net of allowance of $674 ...    18336    20838
# 4                       Income taxes receivable, net      369      355

# %%
total_cash = balsht['12/31/17'].iloc[[0, 1]].sum()

# %%
total_cash == balsht.iloc[2]['12/31/17']
# Out:
# True

# %%
balsht['12/31/17'] = balsht['12/31/17'].map(lambda x: x.replace('(', '-').replace(',', ''))
balsht['12/31/18'] = balsht['12/31/18'].map(lambda x: x.replace('(', '-').replace(',', ''))

# %%
balsht.tail()
# Out:
#                                               Account 12/31/17 12/31/18
# 29  Class A and Class B common stock, and Class C ...    40247    45049
# 30               Accumulated other comprehensive loss     -992    -2306
# 31                                  Retained earnings   113247   134885
# 32                         Total stockholders’ equity   152502   177628
# 33         Total liabilities and stockholders’ equity   197295   232792

# %%
balsht[['12/31/17', '12/31/18']] = balsht[['12/31/17', '12/31/18']].astype(float)
